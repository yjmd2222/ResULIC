# %%
# !CUDA_VISIBLE_DEVICES=1 python inference_win.py \
  --ckpt weights/step=199999.ckpt \
  --config configs/model/stage2/1_1_4/cldm_eps_300_ddim.yaml \
  --input data/test/kodak/image \
  --output output/win/kodak_40 \
  --ddim_steps 3 \
  --ddim_eta 0 \
  --Q 4.0 \
  --add_steps 300

# %%
# !CUDA_VISIBLE_DEVICES=1 python inference_res.py \
  --ckpt weights/step=199999.ckpt \
  --config configs/model/stage2/1_1_4/cldm_eps_300_ddim.yaml \
  --json_file_path data/test/kodak/kodak_captions_40.json \
  --input data/test/kodak/image \
  --output output/res/kodak_40 \
  --ddim_steps 3 \
  --ddim_eta 0 \
  --Q 4.0 \
  --add_steps 300

# %%
# !CUDA_VISIBLE_DEVICES=1 python inference_res_pfo.py \
  --ckpt weights/step=199999.ckpt \
  --config configs/model/stage2/1_1_4/cldm_eps_300_ddim.yaml \
  --json_file_path data/test/kodak/kodak_captions_40.json \
  --input data/test/kodak/image \
  --output output/pfo/kodak_40 \
  --ddim_steps 3 \
  --ddim_eta 0 \
  --Q 4.0 \
  --add_steps 300 \
  --pfo
